# %% [markdown]
# <center>
# <h1> TP-Projet d'optimisation numérique </h1>
# <h1> Année 2020-2021 - 2e année département Sciences du Numérique </h1>
# <h1> Noms: TOUBALI HADAOUI & SENSALI </h1>
# <h1> Prénoms: Faical & Mehdi </h1>
# </center>

# %% [markdown]
# # Algorithme de Newton
# ## Implémentation
#
# 1. Coder l’algorithme de Newton local tel que décrit dans la section *Algorithme de Newton* (fichier `Algorithme_De_Newton.jl`)
#
# 2. Tester l’algorithme sur les fonctions $f_{1}$ , $f_{2}$ avec les points initiaux $x_{011}$ , $x_{012}$ (pour $f_{1}$ ) et $x_{021}$ , $x_{022}$ , $x_{023}$ (pour $f_{2}$ ) donnés en Annexe A.

# %%
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra
using Markdown                             # Pour que les docstrings en début des fonctions ne posent
                                           # pas de soucis. Ces docstrings sont utiles pour générer 
                                           # la documentation sous GitHub
include("Algorithme_De_Newton.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,point_init,xmin,fxmin,flag,sol_exacte,nbiters)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à ",nom_fct, " au point initial ", point_init, ":\n",bold=true,color=:blue)
    if flag != 0 && flag != 1 && flag != 2 && flag != 3
     println("Matrice Hessienne singulière lors d'une étape de calcul")
     println("Dernière Valeur de xmin retrouvée est retournée")
   end
	println("  * xsol = ",xmin)
	println("  * f(xsol) = ",fxmin)
	println("  * nb_iters = ",nbiters)
	println("  * flag = ",flag)
	println("  * sol_exacte : ", sol_exacte)
end



# Fonction f0
# -----------
f0(x) =  sin(x)
# la gradient de la fonction f0
grad_f0(x) = cos(x)
# la hessienne de la fonction f0
hess_f0(x) = -sin(x)
sol_exacte = -pi/2
options = []

# Fonction f1
#----------------
f1(x) = 2*(x[1]+x[2]+x[3]-3)^2 + (x[1]-x[2])^2 + (x[2]-x[3])^2
grad_f1(x) = [4*(x[1]+x[2]+x[3]-3) + 2*(x[1]-x[2]);4*(x[1]+x[2]+x[3]-3) - 2*(x[1]-x[2]) + 2*(x[2]-x[3]) ;4*(x[1]+x[2]+x[3]-3) - 2*(x[2]-x[3]) ]
hess_f1(x) = [6. 2. 4. ; 2. 8. 2. ; 4. 2. 6.] 

x011 = [1.; 0. ;0.]
x012 = [10. ;3. ;-2.2]

# Fonction f2
#----------------
f2(x) = 100(x[2]-x[1]^2)^2 + (1-x[1])^2
grad_f2(x) = [-400*x[1]*(x[2]-x[1]^2)-2*(1-x[1]); 200*(x[2]-x[1]^2)]
hess_f2(x) = [400*(3*x[1]^2 - x[2]) + 2    -400*x[1]   ; -400*x[1]   200]

x021 = [-1.2 ; 1.]
x022 = [10. ; 0.0]
x023 = [0 ; 1/200 + 1/(10^12)]

# f0
x0 = sol_exacte
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters)
x0 = -pi/2+0.5
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters)
x0 = pi/2
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters)

#f1
sol_exacte = [1;1;1]
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f1,grad_f1,hess_f1,x011,options)
my_afficher_resultats("Newton","f1",x011,xmin,f_min,flag,sol_exacte,nb_iters)

xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f1,grad_f1,hess_f1,x012,options)
my_afficher_resultats("Newton","f1",x012,xmin,f_min,flag,sol_exacte,nb_iters)

#f2
sol_exacte = [1;1]
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f2,grad_f2,hess_f2,x021,options)
my_afficher_resultats("Newton","f2",x021,xmin,f_min,flag,sol_exacte,nb_iters)

xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f2,grad_f2,hess_f2,x022,options)
my_afficher_resultats("Newton","f2",x022,xmin,f_min,flag,sol_exacte,nb_iters)

xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f2,grad_f2,hess_f2,x023,options)
my_afficher_resultats("Newton","f2",x023,xmin,f_min,flag,sol_exacte,nb_iters)
# Out:
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial -1.5707963267948966:
#   * xsol = -1.5707963267948966
#   * f(xsol) = -1.0
#   * nb_iters = 1
#   * flag = 0
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial -1.0707963267948966:
#   * xsol = -1.5707963267949088
#   * f(xsol) = -1.0
#   * nb_iters = 3
#   * flag = 0
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial 1.5707963267948966:
#   * xsol = 1.5707963267948966
#   * f(xsol) = 1.0
#   * nb_iters = 1
#   * flag = 0
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f1 au point initial [1.0, 0.0, 0.0]:
# ...

# %% [markdown]
# ## Interprétation
#
# Justifier
#
# 1. les résultats obtenus pour l'exemple $f_0$ ci-dessus;
#
# 2. que l’algorithme implémenté converge en une itération pour $f_{1}$;
#
# 3. que l’algorithme puisse ne pas converger pour $f_{2}$ avec certains points initiaux.

# %% [markdown]
# ## Vos réponses?

# %% [markdown]
#  1. $f_0$ est une fontion sinusoïdale qui change de signe, l'algorithme de newton opère sur des conditions qui portent seulement sur la norme de $f_0$, cela justifie que le signe de f(xsol) varie suivant le point initial.
#
#
#  2. $f_1$ est une fonction polynômiale de degrès 2 alors la solution du problème d'optimisation est exactement égal à : ($H^+$(x))$\nabla{f(x)}$ pour tout x et cela est calculé à l'itération 1 quelque soit le point de départ.
#
#
#  3. La matrice gradient de $f_2$ peut des fois être singulière et cela rend la calcul impossible et donc l'algorithme peut ne pas converger en certains points initiaux (ici le point x023 est un exemple).

# %% [markdown]
# # Régions de confiance avec pas de cauchy
#
# ## Implémentation
#
# 1. Coder l'algorithme du pas de Cauchy d’un sous-problème de
# régions de confiance (fichier `Pas_De_Cauchy.jl`). Tester sur les quadratiques proposées en Annexe B.
#
# 2. Coder l'algorithme de régions de confiance (fichier `Regions_De_Confiance.jl`). Tester sur les problèmes de l’Annexe A.

# %%
# Vos tests
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra
using Markdown         

include("Pas_De_Cauchy.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,s,e,delta,g,H)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à la quadratique ",nom_fct, " définie par : le rayon ", delta, ":\n",bold=true,color=:blue)
	println("  * Le gradient associé à la quadratique ",nom_fct," = ",g)
	println("  * La matrice hessienne associée à la quadratique ",nom_fct," = ",H)
 	println("  * s = ",s)
	println("  * e = ",e)
end

#quadratiques proposées en annexe B  pour différentes valeurs de g et de H
#Les gradients

g1 = [0. ; 0.]
g2 = [6. ; 2.]
g3 = [-2. ; 1.]

#Les matrices hessienes 
H1 = [ 7. 0. ; 0. 2.]
H2 = [ 7. 0. ; 0. 2.]
H3 = [-2. 0. ; 0. 10.]

delta = 10.

s1,e1 = Pas_De_Cauchy(g1,H1, delta)
s2,e2 = Pas_De_Cauchy(g2,H2, delta)
s3,e3 = Pas_De_Cauchy(g3,H3, delta)

my_afficher_resultats("Pas de Cauchy","q1",s1,e1,delta,g1,H1)
my_afficher_resultats("Pas de Cauchy","q2",s2,e2,delta,g2,H2)
my_afficher_resultats("Pas de Cauchy","q3",s3,e3,delta,g3,H3)
# Out:
# -------------------------------------------------------------------------
# Résultats de : Pas de Cauchy appliqué à la quadratique q1 définie par : le rayon 10.0:
#   * Le gradient associé à la quadratique q1 = [0.0, 0.0]
#   * La matrice hessienne associée à la quadratique q1 = [7.0 0.0; 0.0 2.0]
#   * s = [0.0, 0.0]
#   * e = 0
# -------------------------------------------------------------------------
# Résultats de : Pas de Cauchy appliqué à la quadratique q2 définie par : le rayon 10.0:
#   * Le gradient associé à la quadratique q2 = [6.0, 2.0]
#   * La matrice hessienne associée à la quadratique q2 = [7.0 0.0; 0.0 2.0]
#   * s = [-0.9230769230769234, -0.30769230769230776]
#   * e = 1
# -------------------------------------------------------------------------
# Résultats de : Pas de Cauchy appliqué à la quadratique q3 définie par : le rayon 10.0:
#   * Le gradient associé à la quadratique q3 = [-2.0, 1.0]
# ...

# %%
# Vos tests
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra
using Markdown         

include("Pas_De_Cauchy.jl")
include("Regions_De_Confiance.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,point_init,xmin,fxmin,flag,nbiters)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à ",nom_fct, " au point initial ", point_init, ":\n",bold=true,color=:blue)
	println("  * xsol = ",xmin)
	println("  * f(xsol) = ",fxmin)
	println("  * nb_iters = ",nbiters)
	println("  * flag = ",flag)
end

################# Test sur les problèmes de l'annexe 1################
# probleme 1
f1(x) = 2*(x[1]+x[2]+x[3]-3)^2 + (x[1]-x[2])^2 + (x[2]-x[3])^2
grad_f1(x) = [4*(x[1]+x[2]+x[3]-3) + 2*(x[1]-x[2]);4*(x[1]+x[2]+x[3]-3) - 2*(x[1]-x[2]) + 2*(x[2]-x[3]) ;4*(x[1]+x[2]+x[3]-3) - 2*(x[2]-x[3]) ]
hessienne_f1(x) = [6. 2. 4. ; 2. 8. 2. ; 4. 2. 6.] 

x011 = [1.; 0. ;0.]
x012 = [10. ;3. ;-2.2]

# probleme 2
f2(x) = 100(x[2]-x[1]^2)^2 + (1-x[1])^2
grad_f2(x) = [-400*x[1]*(x[2]-x[1]^2)-2*(1-x[1]); 200*(x[2]-x[1]^2)]
hessienne_f2(x) = [400*(3*x[1]^2 - x[2]) + 2    -400*x[1]   ; -400*x[1]   200]

x021 = [-1.2 ; 1.]
x022 = [10. ; 0.0]
x023 = [0 ; 1/200 + 1/(10)^12]

options = []
#####################################################################


xmin,fxmin,flag,nb_iters = Regions_De_Confiance("cauchy",f1,grad_f1,hessienne_f1,x011,options)
my_afficher_resultats("Regions de confiance avec pas de Cauchy","f1",x011,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Regions_De_Confiance("cauchy",f1,grad_f1,hessienne_f1,x012,options)
my_afficher_resultats("Regions de confiance avec pas de Cauchy","f1",x012,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Regions_De_Confiance("cauchy",f2,grad_f2,hessienne_f2,x021,options)
my_afficher_resultats("Regions de confiance avec pas de Cauchy","f2",x021,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Regions_De_Confiance("cauchy",f2,grad_f2,hessienne_f2,x022,options)
my_afficher_resultats("Regions de confiance avec pas de Cauchy","f2",x022,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Regions_De_Confiance("cauchy",f2,grad_f2,hessienne_f2,x023,options)
my_afficher_resultats("Regions de confiance avec pas de Cauchy","f2",x023,xmin,fxmin,flag,nb_iters)
# Out:
# -------------------------------------------------------------------------
# Résultats de : Regions de confiance avec pas de Cauchy appliqué à f1 au point initial [1.0, 0.0, 0.0]:
#   * xsol = [1.0000558873349883, 0.999992420017735, 0.9999289527004819]
#   * f(xsol) = 9.090411079109608e-9
#   * nb_iters = 26
#   * flag = 2
# -------------------------------------------------------------------------
# Résultats de : Regions de confiance avec pas de Cauchy appliqué à f1 au point initial [10.0, 3.0, -2.2]:
#   * xsol = [1.000049795462743, 0.9999961002424803, 0.9999424049876057]
#   * f(xsol) = 6.0401046516733e-9
#   * nb_iters = 28
#   * flag = 2
# -------------------------------------------------------------------------
# Résultats de : Regions de confiance avec pas de Cauchy appliqué à f2 au point initial [-1.2, 1.0]:
#   * xsol = [-0.9273825803596523, 0.8644721781270946]
#   * f(xsol) = 3.716769405269955
#   * nb_iters = 50
#   * flag = 3
# ...

# %%
#Comparaisons de performances en modifiant les paramètres eta1 et eta2
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra
using Markdown         

include("Pas_De_Cauchy.jl")
include("Regions_De_Confiance.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,point_init,xmin,fxmin,flag,nbiters)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à ",nom_fct, " au point initial ", point_init, ":\n",bold=true,color=:blue)
	println("  * xsol = ",xmin)
	println("  * f(xsol) = ",fxmin)
	println("  * nb_iters = ",nbiters)
	println("  * flag = ",flag)
end

################# Test sur les problèmes de l'annexe 1################
# probleme 1
f1(x) = 2*(x[1]+x[2]+x[3]-3)^2 + (x[1]-x[2])^2 + (x[2]-x[3])^2
grad_f1(x) = [4*(x[1]+x[2]+x[3]-3) + 2*(x[1]-x[2]);4*(x[1]+x[2]+x[3]-3) - 2*(x[1]-x[2]) + 2*(x[2]-x[3]) ;4*(x[1]+x[2]+x[3]-3) - 2*(x[2]-x[3]) ]
hessienne_f1(x) = [6. 2. 4. ; 2. 8. 2. ; 4. 2. 6.] 

x011 = [1.; 0. ;0.]
x012 = [10. ;3. ;-2.2]

# probleme 2
f2(x) = 100(x[2]-x[1]^2)^2 + (1-x[1])^2
grad_f2(x) = [-400*x[1]*(x[2]-x[1]^2)-2*(1-x[1]); 200*(x[2]-x[1]^2)]
hessienne_f2(x) = [400*(3*x[1]^2 - x[2]) + 2    -400*x[1]   ; -400*x[1]   200]

x021 = [-1.2 ; 1.]
x022 = [10. ; 0.0]
x023 = [0 ; 1/200 + 1/(10)^12]

options = [10 0.99999999999999999999999 1.0000000000000000000000000000001 0.25 0.75 2 50 sqrt(eps()) 1e-15]
#####################################################################


xmin,fxmin,flag,nb_iters = Regions_De_Confiance("cauchy",f1,grad_f1,hessienne_f1,x011,options)
my_afficher_resultats("Regions de confiance avec pas de Cauchy","f1",x011,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Regions_De_Confiance("cauchy",f1,grad_f1,hessienne_f1,x012,options)
my_afficher_resultats("Regions de confiance avec pas de Cauchy","f1",x012,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Regions_De_Confiance("cauchy",f2,grad_f2,hessienne_f2,x021,options)
my_afficher_resultats("Regions de confiance avec pas de Cauchy","f2",x021,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Regions_De_Confiance("cauchy",f2,grad_f2,hessienne_f2,x022,options)
my_afficher_resultats("Regions de confiance avec pas de Cauchy","f2",x022,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Regions_De_Confiance("cauchy",f2,grad_f2,hessienne_f2,x023,options)
my_afficher_resultats("Regions de confiance avec pas de Cauchy","f2",x023,xmin,fxmin,flag,nb_iters)
# Out:
# -------------------------------------------------------------------------
# Résultats de : Regions de confiance avec pas de Cauchy appliqué à f1 au point initial [1.0, 0.0, 0.0]:
#   * xsol = [1.0000558873349883, 0.999992420017735, 0.9999289527004819]
#   * f(xsol) = 9.090411079109608e-9
#   * nb_iters = 26
#   * flag = 2
# -------------------------------------------------------------------------
# Résultats de : Regions de confiance avec pas de Cauchy appliqué à f1 au point initial [10.0, 3.0, -2.2]:
#   * xsol = [1.000035513687879, 0.9999882483507329, 0.9999409830141056]
#   * f(xsol) = 6.953846757786837e-9
#   * nb_iters = 29
#   * flag = 2
# -------------------------------------------------------------------------
# Résultats de : Regions de confiance avec pas de Cauchy appliqué à f2 au point initial [-1.2, 1.0]:
#   * xsol = [-0.9273825803596523, 0.8644721781270946]
#   * f(xsol) = 3.716769405269955
#   * nb_iters = 50
#   * flag = 3
# ...

# %% [markdown]
# ## Interprétation
#
# 1. Quelle relation lie la fonction test $f_1$ et son modèle de Taylor à l’ordre 2 ? Comparer alors les performances de Newton et RC-Pas de Cauchy sur cette fonction.
#
# 2. Le rayon initial de la région de confiance est un paramètre important dans l’analyse
# de la performance de l’algorithme. Sur quel(s) autre(s) paramètre(s) peut-on jouer
# pour essayer d’améliorer cette performance ? Étudier l’influence d’au moins deux de
# ces paramètres.

# %% [markdown]
# ## Vos réponses?

# %% [markdown]
# 1. la fonction f1 est exactement égale à son developpement de Taylor à l'ordre 2 et donc Newton donnera une solution directe en une seule itération.Ceci explique aue Newton est plus performant que RC-Pas de Cauchy sur cette fonction :
#
#   -x011 : 26 itérations pour RC-Pas de Cauchy comparé à 1 pour Newton
#
#   -x012 : 28 itérations pour RC-Pas de Cauchy comparé à 1 pour Newton
#
#
# 2. On pourrait jouer sur les valeurs de eta1 et eta2 en agrandissant eta1 et en diminuant eta2 pour les rapprocher vers 1 tout en maintenant 0<eta1< eta2<1 et on peut aussi diminuer les valeurs de gamma1 et gamma2 pour agir sur l'évolution de la région de confiance en la rendant plus étroite au fur et à mesure des calcules
# resultats :
#
#     -On remarque pour eta1 = 0.99999999999999999999999
#
#     -eta2 = 1.0000000000000000000000000000001
#
#     -x0 = x022
#
#     -une augmentation nette de la précision de calcul (cf cadre au dessus)

# %% [markdown]
# # Régions de confiance avec gradient conjugué tronqué
#
# ## Implémentation
#
# 1. Implémenter l’algorithme du Gradient Conjugué Tronqué, en se basant sur le cours (fichier `Gradient_Conjugue_Tronque.jl`).
# On validera les résultats sur les fonctions de l’Annexe C.
#
# 2. Intégrer finalement l’algorithme du Gradient Conjugué Tronqué dans le code de
# régions de confiance, et appliquer ce code pour résoudre les exemples proposés en
# Annexe A.

# %%
# Vos tests
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra
using Markdown         

include("Gradient_Conjugue_Tronque.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,s,delta,g,H)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à la quadratique ",nom_fct, " définie par : le rayon ", delta, ":\n",bold=true,color=:blue)
	println("  * Le gradient associé à la quadratique ",nom_fct," = ",g)
	println("  * La matrice hessienne associée à la quadratique ",nom_fct," = ",H)
 	println("  * s = ",s)
end

#quadratiques proposées en annexe C  pour différentes valeurs de g et de H
#Les gradients

g1 = [0. ; 0.]
g2 = [2. ; 3.]
g3 = [2. ; 0.]

#Les matrices hessienes 
H1 = [ -2. 0. ; 0. 10.]
H2 = [ 4. 6. ; 6. 5.]
H3 = [4. 0. ; 0. -15.]

delta = 1.

s1 = Gradient_Conjugue_Tronque(g1,H1, [delta,1000,1e-6])
s2 = Gradient_Conjugue_Tronque(g2,H2, [delta,1000,1e-6])
s3 = Gradient_Conjugue_Tronque(g3,H3, [delta,1000,1e-6])

my_afficher_resultats("Gradient Conjugue Tronque","q1",s1,delta,g1,H1)
my_afficher_resultats("Gradient Conjugue Tronque","q1",s2,delta,g2,H2)
my_afficher_resultats("Gradient Conjugue Tronque","q1",s3,delta,g3,H3)
# Out:
# -------------------------------------------------------------------------
# Résultats de : Gradient Conjugue Tronque appliqué à la quadratique q1 définie par : le rayon 1.0:
#   * Le gradient associé à la quadratique q1 = [0.0, 0.0]
#   * La matrice hessienne associée à la quadratique q1 = [-2.0 0.0; 0.0 10.0]
#   * s = [0.0, 0.0]
# -------------------------------------------------------------------------
# Résultats de : Gradient Conjugue Tronque appliqué à la quadratique q1 définie par : le rayon 1.0:
#   * Le gradient associé à la quadratique q1 = [2.0, 3.0]
#   * La matrice hessienne associée à la quadratique q1 = [4.0 6.0; 6.0 5.0]
#   * s = [0.43504154796251604, -0.9004103795194598]
# -------------------------------------------------------------------------
# Résultats de : Gradient Conjugue Tronque appliqué à la quadratique q1 définie par : le rayon 1.0:
#   * Le gradient associé à la quadratique q1 = [2.0, 0.0]
# ...

# %%
# Vos tests
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra
using Markdown         

include("Gradient_Conjugue_Tronque.jl")
include("Regions_De_Confiance.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,point_init,xmin,fxmin,flag,nbiters)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à ",nom_fct, " au point initial ", point_init, ":\n",bold=true,color=:blue)
	println("  * xsol = ",xmin)
	println("  * f(xsol) = ",fxmin)
	println("  * nb_iters = ",nbiters)
	println("  * flag = ",flag)
end

################# Test sur les problèmes de l'annexe 1################
# probleme 1
f1(x) = 2*(x[1]+x[2]+x[3]-3)^2 + (x[1]-x[2])^2 + (x[2]-x[3])^2
grad_f1(x) = [4*(x[1]+x[2]+x[3]-3) + 2*(x[1]-x[2]);4*(x[1]+x[2]+x[3]-3) - 2*(x[1]-x[2]) + 2*(x[2]-x[3]) ;4*(x[1]+x[2]+x[3]-3) - 2*(x[2]-x[3]) ]
hessienne_f1(x) = [6. 2. 4. ; 2. 8. 2. ; 4. 2. 6.] 

x011 = [1.; 0. ;0.]
x012 = [10. ;3. ;-2.2]

# probleme 2
f2(x) = 100(x[2]-x[1]^2)^2 + (1-x[1])^2
grad_f2(x) = [-400*x[1]*(x[2]-x[1]^2)-2*(1-x[1]); 200*(x[2]-x[1]^2)]
hessienne_f2(x) = [400*(3*x[1]^2 - x[2]) + 2    -400*x[1]   ; -400*x[1]   200]

x021 = [-1.2 ; 1.]
x022 = [10. ; 0.0]
x023 = [0 ; 1/200 + 1/(10)^12]

options = []
#####################################################################


xmin,fxmin,flag,nb_iters = Regions_De_Confiance("gct",f1,grad_f1,hessienne_f1,x011,options)
my_afficher_resultats("Regions de confiance avec la méthode du gradient conjugué tronqué","f1",x011,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Regions_De_Confiance("gct",f1,grad_f1,hessienne_f1,x012,options)
my_afficher_resultats("Regions de confiance avec la méthode du gradient conjugué tronqué","f1",x012,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Regions_De_Confiance("gct",f2,grad_f2,hessienne_f2,x021,options)
my_afficher_resultats("Regions de confiance avec la méthode du gradient conjugué tronqué","f2",x021,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Regions_De_Confiance("gct",f2,grad_f2,hessienne_f2,x022,options)
my_afficher_resultats("Regions de confiance avec la méthode du gradient conjugué tronqué","f2",x022,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Regions_De_Confiance("gct",f2,grad_f2,hessienne_f2,x023,options)
my_afficher_resultats("Regions de confiance avec la méthode du gradient conjugué tronqué","f2",x023,xmin,fxmin,flag,nb_iters)
# Out:
# -------------------------------------------------------------------------
# Résultats de : Regions de confiance avec la méthode du gradient conjugué tronqué appliqué à f1 au point initial [1.0, 0.0, 0.0]:
#   * xsol = [1.0000000000000007, 1.0, 1.0]
#   * f(xsol) = 2.0214560696288428e-30
#   * nb_iters = 1
#   * flag = 0
# -------------------------------------------------------------------------
# Résultats de : Regions de confiance avec la méthode du gradient conjugué tronqué appliqué à f1 au point initial [10.0, 3.0, -2.2]:
#   * xsol = [0.9999999999999996, 1.0000000000000004, 1.0000000000000009]
#   * f(xsol) = 2.5637979419682884e-30
#   * nb_iters = 3
#   * flag = 0
# -------------------------------------------------------------------------
# Résultats de : Regions de confiance avec la méthode du gradient conjugué tronqué appliqué à f2 au point initial [-1.2, 1.0]:
#   * xsol = [0.9999999999999402, 0.9999999999997743]
#   * f(xsol) = 1.1277385526166413e-24
#   * nb_iters = 32
# ...

# %%
# Vos tests
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra
using Markdown         

include("Gradient_Conjugue_Tronque.jl")
include("Pas_De_Cauchy.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,s,delta,g,H,min_quadratique)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à la quadratique ",nom_fct, " définie par : le rayon ", delta, ":\n",bold=true,color=:blue)
	println("  * Le gradient associé à la quadratique ",nom_fct," = ",g)
	println("  * La matrice hessienne associée à la quadratique ",nom_fct," = ",H)
 	println("  * s = ",s)
	println("  * Le minimum de la quadratique  ",nom_fct," = ",min_quadratique)

end

g1 = [6. ; 2.]
g2 = [-2. ; 1.]

#Les matrices hessienes 
H1 = [ 7. 0. ; 0. 2.]
H2 = [-2. 0. ; 0. 10.]

q1(s) = transpose(g1) * s + (1/2) * transpose(s) * H1 * s
q2(s) = transpose(g2) * s + (1/2) * transpose(s) * H2 * s

delta = 15.

s_cauchy1 = Pas_De_Cauchy(g1,H1,delta) 
s_cauchy2 = Pas_De_Cauchy(g2,H2,delta)

s_gc1 = Gradient_Conjugue_Tronque(g1,H1, [delta,1,1e-6])
s_gc2 = Gradient_Conjugue_Tronque(g2,H2, [delta,1,1e-6])


my_afficher_resultats("Gradient Conjugue Tronque","q1",s_gc1,delta,g1,H1,q1(s_gc1))
my_afficher_resultats("Pas De Cauchy","q1",s_cauchy1[1],delta,g1,H1,q1(s_cauchy1[1]))
my_afficher_resultats("Gradient Conjugue Tronque","q2",s_gc2,delta,g2,H2,q2(s_gc2))
my_afficher_resultats("Pas De Cauchy","q2",s_cauchy2[1],delta,g2,H2,q2(s_cauchy2[1]))
# Out:
# -------------------------------------------------------------------------
# Résultats de : Gradient Conjugue Tronque appliqué à la quadratique q1 définie par : le rayon 15.0:
#   * Le gradient associé à la quadratique q1 = [6.0, 2.0]
#   * La matrice hessienne associée à la quadratique q1 = [7.0 0.0; 0.0 2.0]
#   * s = [-0.8571428571428568, -0.9999999999999999]
#   * Le minimum de la quadratique  q1 = -3.571428571428572
# -------------------------------------------------------------------------
# Résultats de : Pas De Cauchy appliqué à la quadratique q1 définie par : le rayon 15.0:
#   * Le gradient associé à la quadratique q1 = [6.0, 2.0]
#   * La matrice hessienne associée à la quadratique q1 = [7.0 0.0; 0.0 2.0]
#   * s = [-0.9230769230769234, -0.30769230769230776]
#   * Le minimum de la quadratique  q1 = -3.076923076923077
# -------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Interprétation
#
# 1. Comparer la décroissance obtenue avec celle du pas de Cauchy, en retournant, dans
# un premier temps le dernier itéré admissible à courbure positive (c’est à dire, que si
# l’une ou l’autre des deux conditions (b) ou (d) sont rencontrées dans l’algorithme 3,
# alors on ne calcule pas ``σ_{j}`` et on retourne le dernier itéré ``s_{j}`` directement).
#
# 2. Comparer la décroissance obtenue avec celle du pas de Cauchy, en imposant la sortie
# dans l’algorithme 3 au bout d’une itération seulement. Que remarquez vous ?
#
# 3. Comparer la décroissance obtenue avec celle du pas de Cauchy dans le cas général.
#
# 4. Quels sont les avantages et inconvénients des deux approches ?

# %% [markdown]
# ## Vos réponses?

# %% [markdown]
# Pour le meme jeu de données comme indiqué dans la cellule précèdente, on trouve les différents résultats :
#
# 1. En modifiant le script du gradient conjugue tronque pour retourner le dernier itéré admissible à courbure positive ( ligne 69 et ligne 72 ), on remarque que le gradient conjugue tronque offre une meilleure approximation dans certains cas et égale dans d'autres par rapport au pas de Cauchy( cf exemple au dessus ).
#
# 2. La décroissance du gradient conjugue tronque est plus rapide que celle obtenue par Pas de Cauchy
#
# 3. Dans le cas général, la décroissance obtenue par le gradient conjugue tronque est meilleure et plus précise que celle obtenue par le pas de cauchy.
#
# 4.  Pas de cauchy :
#
#   - Avantages : Necessite une seule itération donc un seul résultat.
#
#   - incovénients : Moins précis, saturation de la boule dans plusieurs cas.
#
#    Gradient conjugue tronque :
#
#    - Avantages : précision d'ordre supérieure, converge plus rapidement vers le minimum.
#
#    - incovénients : une complexité spatiale plus grande.

# %% [markdown]
# # Lagrangien augmenté
#
# ## Implémentation
# 1.Choisir des critères d’arrêt pour la convergence de l'algorithme.
#
# 2.Implémenter l'algorithme du lagrangien augmenté, en utilisant les différentes méthodes
# qui ont été vues en première partie pour la résolution de la suite de problémes sans
# contraintes (fichier `Lagrangien_Augmente.jl`)
#
# 3.Tester les différentes variantes sur les problèmes en Annexe D.

# %%
# Vos tests
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra
using Markdown         

include("Lagrangien_Augmente.jl")
include("Algorithme_De_Newton.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,nom_contrainte,point_init,xmin,fxmin,flag,nbiters)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à ",nom_fct, " au point initial ", point_init,"\n","avec la contrainte ",nom_contrainte," = 0", ":\n",bold=true,color=:blue)
	println("  * xsol = ",xmin)
	println("  * f(xsol) = ",fxmin)
	println("  * nb_iters = ",nbiters)
	println("  * flag = ",flag)
end

################# Test sur les problèmes de l'annexe 1################
# probleme 1
f1(x) = 2*(x[1]+x[2]+x[3]-3)^2 + (x[1]-x[2])^2 + (x[2]-x[3])^2
grad_f1(x) = [4*(x[1]+x[2]+x[3]-3) + 2*(x[1]-x[2]);4*(x[1]+x[2]+x[3]-3) - 2*(x[1]-x[2]) + 2*(x[2]-x[3]) ;4*(x[1]+x[2]+x[3]-3) - 2*(x[2]-x[3]) ]
hessienne_f1(x) = [6. 2. 4. ; 2. 8. 2. ; 4. 2. 6.] 
contrainte_1(x) = x[1] + x[3] - 1
grad_contrainte_1(x) = [1 ;0;1]
hess_contrainte_1(x) = [0 0 0;0 0 0; 0 0 0]

x011 = [1.; 0. ;0.]
x012 = [10. ;3. ;-2.2]

# probleme 2
f2(x) = 100(x[2]-x[1]^2)^2 + (1-x[1])^2
grad_f2(x) = [-400*x[1]*(x[2]-x[1]^2)-2*(1-x[1]); 200*(x[2]-x[1]^2)]
hessienne_f2(x) = [400*(3*x[1]^2 - x[2]) + 2    -400*x[1]   ; -400*x[1]   200]
contrainte_2(x) =  (x[1]^2) + (x[2]^2) -1.5
grad_contrainte_2(x) = [2*x[1] ;2*x[2]]
hess_contrainte_2(x) = [2 0;0 2]

x021 = [-1.2 ; 1.]
x022 = [10. ; 0.0]
x023 = [0 ; 1/200 + 1/(10)^12]

options = []
#####################################################################


xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("newton",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x011,options)
my_afficher_resultats("lagrangien augmenté avec newton","f1","x1 + x3 -1",x011,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("newton",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x012,options)
my_afficher_resultats("lagrangien augmenté avec newton","f1","x1 + x3 -1",x012,xmin,fxmin,flag,nb_iters)
    
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("newton",f2,contrainte_2,grad_f2,hessienne_f2,grad_contrainte_2,hess_contrainte_2,x021,options)
my_afficher_resultats("lagrangien augmenté avec newton","f2","x1^2 + x2^2 -1",x021,xmin,fxmin,flag,nb_iters)
    
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("newton",f2,contrainte_2,grad_f2,hessienne_f2,grad_contrainte_2,hess_contrainte_2,x022,options)
my_afficher_resultats("lagrangien augmenté avec newton","f2","x1^2 + x2^2 -1",x022,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("newton",f2,contrainte_2,grad_f2,hessienne_f2,grad_contrainte_2,hess_contrainte_2,x023,options)
my_afficher_resultats("lagrangien augmenté avec newton","f2","x1^2 + x2^2 -1",x023,xmin,fxmin,flag,nb_iters)
# Out:
# -------------------------------------------------------------------------
# Résultats de : lagrangien augmenté avec newton appliqué à f1 au point initial [1.0, 0.0, 0.0]
# avec la contrainte x1 + x3 -1 = 0:
#   * xsol = [0.5000000001207724, 1.2499999999396139, 0.5000000001207721]
#   * f(xsol) = 2.2499999989130504
#   * nb_iters = 7
#   * flag = 0
# -------------------------------------------------------------------------
# Résultats de : lagrangien augmenté avec newton appliqué à f1 au point initial [10.0, 3.0, -2.2]
# avec la contrainte x1 + x3 -1 = 0:
#   * xsol = [0.5000002494183198, 1.2499998752908401, 0.5000002494183197]
#   * f(xsol) = 2.249997755235682
#   * nb_iters = 5
#   * flag = 0
# -------------------------------------------------------------------------
# Résultats de : lagrangien augmenté avec newton appliqué à f2 au point initial [-1.2, 1.0]
# avec la contrainte x1^2 + x2^2 -1 = 0:
#   * xsol = [-0.9048734396275231, 0.8253506897481885]
# ...

# %%
# Vos tests
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra
using Markdown         

include("Lagrangien_Augmente.jl")
include("Pas_De_Cauchy.jl")
include("Regions_De_Confiance.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,nom_contrainte,point_init,xmin,fxmin,flag,nbiters)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à ",nom_fct, " au point initial ", point_init,"\n","avec la contrainte ",nom_contrainte," = 0", ":\n",bold=true,color=:blue)
	println("  * xsol = ",xmin)
	println("  * f(xsol) = ",fxmin)
	println("  * nb_iters = ",nbiters)
	println("  * flag = ",flag)
end

################# Test sur les problèmes de l'annexe 1################
# probleme 1
f1(x) = 2*(x[1]+x[2]+x[3]-3)^2 + (x[1]-x[2])^2 + (x[2]-x[3])^2
grad_f1(x) = [4*(x[1]+x[2]+x[3]-3) + 2*(x[1]-x[2]);4*(x[1]+x[2]+x[3]-3) - 2*(x[1]-x[2]) + 2*(x[2]-x[3]) ;4*(x[1]+x[2]+x[3]-3) - 2*(x[2]-x[3]) ]
hessienne_f1(x) = [6. 2. 4. ; 2. 8. 2. ; 4. 2. 6.] 
contrainte_1(x) = x[1] + x[3] - 1
grad_contrainte_1(x) = [1 ;0;1]
hess_contrainte_1(x) = [0 0 0;0 0 0; 0 0 0]

x011 = [1.; 0. ;0.]
x012 = [10. ;3. ;-2.2]


# probleme 2
f2(x) = 100(x[2]-x[1]^2)^2 + (1-x[1])^2
grad_f2(x) = [-400*x[1]*(x[2]-x[1]^2)-2*(1-x[1]); 200*(x[2]-x[1]^2)]
hessienne_f2(x) = [400*(3*x[1]^2 - x[2]) + 2    -400*x[1]   ; -400*x[1]   200]
contrainte_2(x) =  (x[1]^2) + (x[2]^2) -1.5
grad_contrainte_2(x) = [2*x[1] ;2*x[2]]
hess_contrainte_2(x) = [2 0;0 2]

x021 = [-1.2 ; 1.]
x022 = [10. ; 0.0]
x023 = [0 ; 1/200 + 1/(10)^12]

options = []
#####################################################################


xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("cauchy",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x011,options)
my_afficher_resultats("lagrangien augmenté avec cauchy","f1","x1 + x3 -1",x011,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("cauchy",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x012,options)
my_afficher_resultats("lagrangien augmenté avec cauchy","f1","x1 + x3 -1",x012,xmin,fxmin,flag,nb_iters)
    
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("cauchy",f2,contrainte_2,grad_f2,hessienne_f2,grad_contrainte_2,hess_contrainte_2,x021,options)
my_afficher_resultats("lagrangien augmenté avec cauchy","f2","x1^2 + x2^2 -1",x021,xmin,fxmin,flag,nb_iters)
    
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("cauchy",f2,contrainte_2,grad_f2,hessienne_f2,grad_contrainte_2,hess_contrainte_2,x022,options)
my_afficher_resultats("lagrangien augmenté avec cauchy","f2","x1^2 + x2^2 -1",x022,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("cauchy",f2,contrainte_2,grad_f2,hessienne_f2,grad_contrainte_2,hess_contrainte_2,x023,options)
my_afficher_resultats("lagrangien augmenté avec cauchy","f2","x1^2 + x2^2 -1",x023,xmin,fxmin,flag,nb_iters)
# Out:
# -------------------------------------------------------------------------
# Résultats de : lagrangien augmenté avec cauchy appliqué à f1 au point initial [1.0, 0.0, 0.0]
# avec la contrainte x1 + x3 -1 = 0:
#   * xsol = [0.5000000045362856, 1.2500000032942178, 0.4999999962008131]
#   * f(xsol) = 2.2499999966830555
#   * nb_iters = 7
#   * flag = 0
# -------------------------------------------------------------------------
# Résultats de : lagrangien augmenté avec cauchy appliqué à f1 au point initial [10.0, 3.0, -2.2]
# avec la contrainte x1 + x3 -1 = 0:
#   * xsol = [0.5000002673953304, 1.2499999123648984, 0.5000001839858162]
#   * f(xsol) = 2.249997968785304
#   * nb_iters = 5
#   * flag = 0
# -------------------------------------------------------------------------
# Résultats de : lagrangien augmenté avec cauchy appliqué à f2 au point initial [-1.2, 1.0]
# avec la contrainte x1^2 + x2^2 -1 = 0:
#   * xsol = [-0.9048734623140892, 0.8253507308345561]
# ...

# %%
# Vos tests
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra
using Markdown         

include("Lagrangien_Augmente.jl")
include("Gradient_Conjugue_Tronque.jl")
include("Regions_De_Confiance.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,nom_contrainte,point_init,xmin,fxmin,flag,nbiters)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à ",nom_fct, " au point initial ", point_init,"\n","avec la contrainte ",nom_contrainte," = 0", ":\n",bold=true,color=:blue)
	println("  * xsol = ",xmin)
	println("  * f(xsol) = ",fxmin)
	println("  * nb_iters = ",nbiters)
	println("  * flag = ",flag)
end

################# Test sur les problèmes de l'annexe 1################
# probleme 1
f1(x) = 2*(x[1]+x[2]+x[3]-3)^2 + (x[1]-x[2])^2 + (x[2]-x[3])^2
grad_f1(x) = [4*(x[1]+x[2]+x[3]-3) + 2*(x[1]-x[2]);4*(x[1]+x[2]+x[3]-3) - 2*(x[1]-x[2]) + 2*(x[2]-x[3]) ;4*(x[1]+x[2]+x[3]-3) - 2*(x[2]-x[3]) ]
hessienne_f1(x) = [6. 2. 4. ; 2. 8. 2. ; 4. 2. 6.] 
contrainte_1(x) = x[1] + x[3] - 1
grad_contrainte_1(x) = [1 ;0;1]
hess_contrainte_1(x) = [0 0 0;0 0 0; 0 0 0]

x011 = [1.; 0. ;0.]
x012 = [10. ;3. ;-2.2]


# probleme 2
f2(x) = 100(x[2]-x[1]^2)^2 + (1-x[1])^2
grad_f2(x) = [-400*x[1]*(x[2]-x[1]^2)-2*(1-x[1]); 200*(x[2]-x[1]^2)]
hessienne_f2(x) = [400*(3*x[1]^2 - x[2]) + 2    -400*x[1]   ; -400*x[1]   200]
contrainte_2(x) =  (x[1]^2) + (x[2]^2) -1.5
grad_contrainte_2(x) = [2*x[1] ;2*x[2]]
hess_contrainte_2(x) = [2 0;0 2]

x021 = [-1.2 ; 1.]
x022 = [10. ; 0.0]
x023 = [0 ; 1/200 + 1/(10)^12]


options = []
#####################################################################


xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x011,options)
my_afficher_resultats("lagrangien augmenté avec gct","f1","x1 + x3 -1.5",x011,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x012,options)
my_afficher_resultats("lagrangien augmenté avec gct","f1","x1 + x3 -1.5",x012,xmin,fxmin,flag,nb_iters)
    
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f2,contrainte_2,grad_f2,hessienne_f2,grad_contrainte_2,hess_contrainte_2,x021,options)
my_afficher_resultats("lagrangien augmenté avec gct","f2","x1^2 + x2^2 -1.5",x021,xmin,fxmin,flag,nb_iters)
    
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f2,contrainte_2,grad_f2,hessienne_f2,grad_contrainte_2,hess_contrainte_2,x022,options)
my_afficher_resultats("lagrangien augmenté avec gct","f2","x1^2 + x2^2 -1.5",x022,xmin,fxmin,flag,nb_iters)

xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f2,contrainte_2,grad_f2,hessienne_f2,grad_contrainte_2,hess_contrainte_2,x023,options)
my_afficher_resultats("lagrangien augmenté avec gct","f2","x1^2 + x2^2 -1.5",x023,xmin,fxmin,flag,nb_iters)

###########################################################################
options = [1e-8 1e-5 50 20000 1000000 2]
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x011,options)
my_afficher_resultats("lagrangien augmenté avec gct en augmentant lamba0 et mu0","f1","x1 + x3 -1.5",x011,xmin,fxmin,flag,nb_iters)

options = [1e-8 1e-5 50 0.0002 0.01 2]
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x011,options)
my_afficher_resultats("lagrangien augmenté avec gct en diminuant lamba0 et mu0","f1","x1 + x3 -1.5",x011,xmin,fxmin,flag,nb_iters)

options = [1e-8 1e-5 50 0.0002 1000000 2]
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x011,options)
my_afficher_resultats("lagrangien augmenté avec gct en diminuant lamba0 et en augmentant mu0","f1","x1 + x3 -1.5",x011,xmin,fxmin,flag,nb_iters)

options = [1e-8 1e-5 50 20000 0.01 2]
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x011,options)
my_afficher_resultats("lagrangien augmenté avec gct en augmentant lamba0 et en diminuant mu0","f1","x1 + x3 -1.5",x011,xmin,fxmin,flag,nb_iters)

options = [1e-8 1e-5 50 20000 100 2]
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x011,options)
my_afficher_resultats("lagrangien augmenté avec gct en augmentant lamba0","f1","x1 + x3 -1.5",x011,xmin,fxmin,flag,nb_iters)

options = [1e-8 1e-5 50 0.0002 100 2]
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x011,options)
my_afficher_resultats("lagrangien augmenté avec gct en diminuant lamba0","f1","x1 + x3 -1.5",x011,xmin,fxmin,flag,nb_iters)

options = [1e-8 1e-5 50 2 1000000 2]
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x011,options)
my_afficher_resultats("lagrangien augmenté avec gct en augmentant mu0","f1","x1 + x3 -1.5",x011,xmin,fxmin,flag,nb_iters)

options = [1e-8 1e-5 5000 2 0.01 2]
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x011,options)
my_afficher_resultats("lagrangien augmenté avec gct en diminuant mu0","f1","x1 + x3 -1.5",x011,xmin,fxmin,flag,nb_iters)

options = [1e-8 1e-5 50 2 100 20000]
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x011,options)
my_afficher_resultats("lagrangien augmenté avec gct en augmentant tho","f1","x1 + x3 -1.5",x011,xmin,fxmin,flag,nb_iters)

options = [1e-8 1e-5 50 2 100 0.0002]
xmin,fxmin,flag,nb_iters = Lagrangien_Augmente("gct",f1,contrainte_1,grad_f1,hessienne_f1,grad_contrainte_1,hess_contrainte_1,x011,options)
my_afficher_resultats("lagrangien augmenté avec gct en diminuant tho","f1","x1 + x3 -1.5",x011,xmin,fxmin,flag,nb_iters)
# Out:
# -------------------------------------------------------------------------
# Résultats de : lagrangien augmenté avec gct appliqué à f1 au point initial [1.0, 0.0, 0.0]
# avec la contrainte x1 + x3 -1.5 = 0:
#   * xsol = [0.5000000001207721, 1.2499999999396139, 0.5000000001207725]
#   * f(xsol) = 2.24999999891305
#   * nb_iters = 7
#   * flag = 0
# -------------------------------------------------------------------------
# Résultats de : lagrangien augmenté avec gct appliqué à f1 au point initial [10.0, 3.0, -2.2]
# avec la contrainte x1 + x3 -1.5 = 0:
#   * xsol = [0.5000002494183216, 1.2499998752908401, 0.5000002494183174]
#   * f(xsol) = 2.2499977552356842
#   * nb_iters = 5
#   * flag = 0
# -------------------------------------------------------------------------
# Résultats de : lagrangien augmenté avec gct appliqué à f2 au point initial [-1.2, 1.0]
# avec la contrainte x1^2 + x2^2 -1.5 = 0:
#   * xsol = [-0.9048734396275231, 0.8253506897481885]
#   * f(xsol) = 3.6328392931390914
# ...

# %% [markdown]
# ## Interprétation
#  1.Commenter les résultats obtenus, en étudiant notamment les valeurs de $\lambda_k$ et $\mu_k$.
#
#  2.Étudier l'influence du paramètre $\tau$ dans la performance de l'algorithme.
#
#  3.**Supplémentaire** :
#       Que proposez-vous comme méthode pour la résolution des problèmes avec
#       des contraintes à la fois d'égalité et d'inégalité ? Implémenter (si le temps le permet)
#       ce nouvel algorithme

# %% [markdown]
# ## Vos réponses?

# %% [markdown]
# 1. mu0 :D'après l'analyse des différents cas il sied de retenir qu'une diminution de mu0 entraine une stagnation de l'algorithme         avec une solution non adéquate, en revanche une augmentation de mu0 produit une résultat bien plus précis.
#    lambda0 :Une modification de lambda0 n'entraîne pas un changement considérable de l'algorithme.
#
#
# 2. D'après les résultats obtenus :
#  * Augmenter Tho produit des résultats plus précis
#  * Diminuer Tho produit des résulats moins précis.
#
#    Conclusion : Il faut augmenter Tho pour améliorer la précision.
